# %%
# !pip install transformers

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
classifier = pipeline(
    "zero-shot-classification",
    model="facebook/bart-large-mnli"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
labels = ["Horror", "Comedy", "Action"]

# %%
plot = input("Enter the movie plot summary:\n")
# Out:
# Enter the movie plot summary:
# McCauley, a professional thief, hopes to pull off one last heist before he retires. However, he is under the constant surveillance of a police detective, Hanna, who tries to thwart his plan.

# %%
result = classifier(plot, labels)

print("\nPredicted Genre:", result["labels"][0])
print("Confidence Scores:")

for label, score in zip(result["labels"], result["scores"]):
    print(f"{label}: {score:.2f}")
# Out:
# Predicted Genre: Action
# Confidence Scores:
# Action: 0.59
# Comedy: 0.21
# Horror: 0.20

# %%
# Prediction: Informative (84.58% confidence)

# ---

# # Project: Clickbait Title Detector

# **Author:** AAYAN VIKRAM SINGH
# **SRN:** PES2UG23CS014

# ---

# ## 1. Overview

# This project is an AI tool designed to analyze video titles or news headlines and classify them as either **"Clickbait"** or **"Informative"** content automatically.

# ---

# ## 2. Methodology

# I used the **Hugging Face Transformers** library to implement this solution.

# - **Task:** Zero-Shot Text Classification
# - **Model:** `facebook/bart-large-mnli`
# - **Approach:**
#   Instead of training a model on thousands of clickbait examples, I used a **Zero-Shot** approach. This model allows me to provide custom labels (**Clickbait**, **Informative**) at runtime, and it predicts the best fit based on its pre-trained understanding of the English language.

# ---

# ## 3. Observations

# The model performed exceptionally well on standard clickbait phrases.

# - **Success Case:** *"You Won't Believe This!"* was correctly identified as **Clickbait** with over 90% confidence.
# - **Success Case:** Factual headlines like *"NASA Launches Satellite"* were correctly identified as **Informative**.
